# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Basic graph

# %%
x = np.array([0,1,2,3,4])
y = np.array([0,2,4,6,8])

#Resize your graph
# plt.figure(figsize=(5,2),dpi=300)

#Line no 1
#plt.plot(x,y,label='2X',color='yellow',linewidth=2,marker='s',markersize=10,markeredgecolor='blue',linestyle='--')
plt.plot(x,y,'b^--',label='2x')
plt.title('Our first graph',fontdict = {'fontname': 'Calibri','fontsize':20})

#Line no 2
x2 = np.arange(0,4.5,0.5)
#plt.plot(x2,x2**2,label='Curve',marker='o',color='red',markeredgecolor='black')
plt.plot(x2[:6],x2[:6]**2,'r',label='x^2')
plt.plot(x2[5:],x2[5:]**2,'r--')
plt.plot()

plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.xticks([0,1,2,3,4])
# plt.yticks([0,2,4,6,8,10])
plt.legend()

#To save the graph (**Always write this line before plt.show() otherwise it won't be saved)
plt.savefig('mygraph.png',dpi=300)

plt.show()

# %%
x2
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. ])

# %% [markdown]
# **Bar Chart**

# %%
labels = ['A','B','C']
values = [1,4,2]
bars = plt.bar(labels,values)

patterns = ['/','o','*']
for x in bars:
    x.set_hatch(patterns.pop())
    
# bars[0].set_hatch('/')
# bars[1].set_hatch('o')
# bars[2].set_hatch('*')

plt.figure(figsize=(3,2))

plt.show()

# %% [markdown]
# **Real World Examples**

# %%
gas = pd.read_csv('gas_prices.csv')
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
plt.figure(figsize=(10,5))

#BASIC WAY TO PLOT
plt.plot(gas.Year,gas.USA,'b.-',label='USA')
plt.plot(gas.Year,gas.Canada,'r.-',label='Canada')
plt.plot(gas.Year,gas['South Korea'],'g.-',label='South Korea')
plt.plot(gas.Year,gas['France'],'y.-',label='France')
plt.plot(gas.Year,gas['Australia'],'c.-',label='Australia')

#ANOTHER WAY TO PLOT MANY VALUES
#WAY 1
# for country in gas:
#     if country!='Year':
#         plt.plot(gas.Year,gas[country],marker='.',label=country)

#WAY2
# countries_to_look_at = ['Australia','France','Italy','UK','Germany']
# for country in gas:
#     if country in countries_to_look_at:
#         plt.plot(gas.Year,gas[country],marker='.',label=country)
        
        
plt.title('Gas prices over Time (in USD)',fontdict={'fontweight':'bold', 'fontsize':12})
plt.xlabel('Year')
plt.ylabel('US Dollars')
plt.legend()

#for also adding a new year
plt.xticks(gas.Year[::3].tolist()+[2011]) #Every three years
print(gas.Year[::3])
#For moving the legend outside of the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left') 

plt.savefig('Gas_Price_Figure.png',dpi=300)

plt.show()
# Out:
# 0     1990
# 3     1993
# 6     1996
# 9     1999
# 12    2002
# 15    2005
# 18    2008
# Name: Year, dtype: int64

# %% [markdown]
# ### Load fifa Data

# %%
fifa = pd.read_csv('fifa_data.csv')
fifa
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %% [markdown]
# **Histograms**

# %%
bins = [40,50,60,70,80,90,100]
plt.hist(fifa.Overall,bins=bins,color='#d669c0')  #search color picker on google 
plt.xticks(bins)
plt.xlabel('Skill level')
plt.ylabel('Number of Players')
plt.title('Distribution of Player skills in FIFA 2018')
plt.show()

# %% [markdown]
# **Pie Chart**

# %%
left = fifa.loc[fifa['Preferred Foot']=='Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot']=='Right'].count()[0]
# print(left,right)
labels = ['Left','Right']
colors = ['#64e3df','#8a1627']
plt.pie([left,right],labels = labels,colors=colors,autopct = '%.2f %%')
plt.title('Foot preference of FIFA players')
plt.show()
# Out:
# C:\Users\KOYELISHA\AppData\Local\Temp\ipykernel_7832\1187546753.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   left = fifa.loc[fifa['Preferred Foot']=='Left'].count()[0]
# C:\Users\KOYELISHA\AppData\Local\Temp\ipykernel_7832\1187546753.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   right = fifa.loc[fifa['Preferred Foot']=='Right'].count()[0]

# %%
fifa.Weight = [int(x.strip('lbs')) if type(x)==str else x for x in fifa.Weight]
plt.style.use('ggplot')
light = fifa.loc[fifa.Weight<125].count()[0]
light_medium = fifa.loc[fifa.Weight>=125 & (fifa.Weight<150)].count()[0]
medium = fifa[(fifa.Weight>=150) & (fifa.Weight<175)].count()[0]
medium_heavy = fifa[(fifa.Weight>=175) & (fifa.Weight<200)].count()[0]
heavy =fifa[(fifa.Weight>=200)].count()[0]
weights = [light,light_medium,medium,medium_heavy,heavy]
labels = ['Under 125','125-150','150-175','175-200','Over 200']
explode = (.4,0.1,0.1,0.1,.4)
plt.pie(weights,labels = labels,autopct='%.2f %%',pctdistance=0.8,explode=explode)
plt.title('Weight Distribution of FIFA players(in lbs)')
plt.show()
# Out:
# C:\Users\KOYELISHA\AppData\Local\Temp\ipykernel_7832\779479777.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   light = fifa.loc[fifa.Weight<125].count()[0]
# C:\Users\KOYELISHA\AppData\Local\Temp\ipykernel_7832\779479777.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   light_medium = fifa.loc[fifa.Weight>=125 & (fifa.Weight<150)].count()[0]
# ...

# %%
plt.style.use('default')

plt.figure(figsize=(8,8))

barcelona = fifa.loc[fifa.Club=='FC Barcelona']['Overall']
madrid = fifa.loc[fifa.Club=='Real Madrid']['Overall']
revs = fifa.loc[fifa.Club=='New England Revolution']['Overall']
psg = fifa.loc[fifa.Club=='Paris Saint-Germain']['Overall']
Juventus = fifa.loc[fifa.Club=='Juventus']['Overall']

labels = ['FC Barcelona','Real Madrid','NE Revolution','Paris Saint-Germain','Juventus']
plt.title('Professional Football Team Comparison')
plt.ylabel('FIFA Overall rating')
boxes = plt.boxplot([barcelona,madrid,revs,psg,Juventus],labels = labels,patch_artist=True,medianprops={'linewidth':2})

for box in boxes['boxes']:
    #setting the edge colors
    box.set(color='#59c3e3',linewidth=2)
    #Change the fill color
    box.set(facecolor='#f7e5ab')

plt.show()
# Out:
# C:\Users\KOYELISHA\AppData\Local\Temp\ipykernel_7832\1241405746.py:14: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   boxes = plt.boxplot([barcelona,madrid,revs,psg,Juventus],labels = labels,patch_artist=True,medianprops={'linewidth':2})
